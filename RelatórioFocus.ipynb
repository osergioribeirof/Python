# %% [markdown]
# * Python BCB: https://wilsonfreitas.github.io/python-bcb
#
# * API de Expectativas: https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/documentacao

# %% [markdown]
# # BIBLIOTECAS

# %%
# !pip install python-bcb

# %%
from bcb import Expectativas

# %% [markdown]
# # WEB SCRAPING BCB

# %%
em = Expectativas()

# %%
em.describe()
# Out:
# EntitySets:
#   ExpectativasMercadoTop5Anuais
#   ExpectativaMercadoMensais
#   ExpectativasMercadoInflacao24Meses
#   ExpectativasMercadoInflacao12Meses
#   ExpectativasMercadoSelic
#   ExpectativasMercadoTop5Selic
#   ExpectativasMercadoTop5Mensais
#   ExpectativasMercadoTrimestrais
#   ExpectativasMercadoAnuais

# %%
ep = em.get_endpoint("ExpectativasMercadoAnuais")

# %%
def get_previsoes(indicador, ano):
    return  (ep.query()
        .filter(ep.Indicador == f"{indicador}")
        .filter(ep.Data >= f'{ano}-01-01')
        .filter(ep.DataReferencia == ano)
        .select(ep.Data, ep.Mediana)
        .collect())

# %% [markdown]
# # PREVISÕES BOLETIM FOCUS

# %% [markdown]
# ### Previsão IPCA (Boletim Focus)

# %%
get_previsoes('IPCA', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   4.9944
# 1  2025-01-02   4.9978
# 2  2025-01-03   4.9932
# 3  2025-01-03   4.9932
# 4  2025-01-06   4.9977
# ..        ...      ...
# 59 2025-02-12   5.5706
# 60 2025-02-13   5.5944
# 61 2025-02-13   5.5612
# 62 2025-02-14   5.6026
# 63 2025-02-14   5.5800
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão PIB (Boletim Focus)

# %%
get_previsoes('PIB Total', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   2.0155
# 1  2025-01-02   2.1162
# 2  2025-01-03   2.0190
# 3  2025-01-03   2.0567
# 4  2025-01-06   2.0000
# ..        ...      ...
# 59 2025-02-12   2.0123
# 60 2025-02-13   2.0058
# 61 2025-02-13   2.0120
# 62 2025-02-14   2.0062
# 63 2025-02-14   2.0767
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão Câmbio (Boletim Focus)

# %%
get_previsoes('Câmbio', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   5.9997
# 1  2025-01-02   6.0000
# 2  2025-01-03   5.9999
# 3  2025-01-03   6.0000
# 4  2025-01-06   5.9997
# ..        ...      ...
# 59 2025-02-12   6.0000
# 60 2025-02-13   6.0000
# 61 2025-02-13   5.9750
# 62 2025-02-14   6.0000
# 63 2025-02-14   5.9500
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão Selic (Boletim Focus)

# %%
get_previsoes('Selic', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02     15.0
# 1  2025-01-02     15.0
# 2  2025-01-03     15.0
# 3  2025-01-03     15.0
# 4  2025-01-06     15.0
# ..        ...      ...
# 59 2025-02-12     15.0
# 60 2025-02-13     15.0
# 61 2025-02-13     15.0
# 62 2025-02-14     15.0
# 63 2025-02-14     15.0
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão IGPM Variação (Boletim Focus)

# %%
get_previsoes('IGP-M', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   4.8741
# 1  2025-01-02   4.7997
# 2  2025-01-03   4.8741
# 3  2025-01-03   4.7981
# 4  2025-01-06   4.8871
# ..        ...      ...
# 59 2025-02-12   4.9994
# 60 2025-02-13   5.0300
# 61 2025-02-13   4.9658
# 62 2025-02-14   5.0300
# 63 2025-02-14   4.7400
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão IPCA Administrados (Boletim Focus)

# %%
get_previsoes('IPCA Administrados', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   4.4086
# 1  2025-01-02   4.1360
# 2  2025-01-03   4.4180
# 3  2025-01-03   4.1869
# 4  2025-01-06   4.4180
# ..        ...      ...
# 59 2025-02-12   4.9500
# 60 2025-02-13   5.0377
# 61 2025-02-13   4.8992
# 62 2025-02-14   5.0257
# 63 2025-02-14   4.8297
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão Conta Corrente (US bilhões)

# %%
get_previsoes('Conta corrente', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   -50.00
# 1  2025-01-02   -52.00
# 2  2025-01-03   -50.00
# 3  2025-01-03   -53.50
# 4  2025-01-06   -50.00
# ..        ...      ...
# 59 2025-02-12   -52.25
# 60 2025-02-13   -52.00
# 61 2025-02-13   -52.50
# 62 2025-02-14   -52.00
# 63 2025-02-14   -55.00
#
# [64 rows x 2 columns]

# %% [markdown]
# ###Previsão Balança Comercial (US bilhões)

# %%
get_previsoes('Balança Comercial', 2025)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Previsão Investimento direto no país (US$ bilhões)

# %%
get_previsoes('Investimento direto no país ', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02     70.0
# 1  2025-01-02     70.0
# 2  2025-01-03     70.0
# 3  2025-01-03     67.3
# 4  2025-01-06     70.0
# ..        ...      ...
# 59 2025-02-12     70.0
# 60 2025-02-13     70.0
# 61 2025-02-13     70.0
# 62 2025-02-14     70.0
# 63 2025-02-14     74.0
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão Dívida líquida do setor público (% do PIB)

# %%
get_previsoes('Dívida líquida do setor público ', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02    67.00
# 1  2025-01-02    66.00
# 2  2025-01-03    66.95
# 3  2025-01-03    66.00
# 4  2025-01-06    67.00
# ..        ...      ...
# 59 2025-02-12    66.20
# 60 2025-02-13    66.10
# 61 2025-02-13    65.60
# 62 2025-02-14    66.10
# 63 2025-02-14    66.20
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Previsão Resultado primário (% do PIB)

# %%
get_previsoes('Resultado primário ', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   -0.600
# 1  2025-01-02   -0.685
# 2  2025-01-03   -0.600
# 3  2025-01-03   -0.700
# 4  2025-01-06   -0.600
# ..        ...      ...
# 59 2025-02-12   -0.600
# 60 2025-02-13   -0.600
# 61 2025-02-13   -0.600
# 62 2025-02-14   -0.600
# 63 2025-02-14   -0.570
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Resultado nominal (% do PIB)

# %%
get_previsoes('Resultado nominal ', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   -8.380
# 1  2025-01-02   -8.000
# 2  2025-01-03   -8.380
# 3  2025-01-03   -7.700
# 4  2025-01-06   -8.390
# ..        ...      ...
# 59 2025-02-12   -8.850
# 60 2025-02-13   -8.915
# 61 2025-02-13   -8.650
# 62 2025-02-14   -8.965
# 63 2025-02-14   -8.900
#
# [64 rows x 2 columns]
