# %% [markdown]
# <a href="https://colab.research.google.com/github/osergioribeirof/Python/blob/main/DRE__E_Balan%C3%A7o_Patrimonial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Biblioteca

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ### Ativo

# %%
ativo = yf.Ticker('VALE3.SA')

# %% [markdown]
# ### Dados Trimestre

# %%
dre = ativo.get_financials(freq='quarterly')
dre
# Out:
#                                                            2024-09-30  \
# TaxEffectOfUnusualItems                              103744774.477448
# TaxRateForCalcs                                              0.123212
# NormalizedEBITDA                                         2955000000.0
# TotalUnusualItems                                         842000000.0
# TotalUnusualItemsExcludingGoodwill                        842000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       2412000000.0
# ReconciledDepreciation                                    748000000.0
# ReconciledCostOfRevenue                                  5547000000.0
# EBITDA                                                   3797000000.0
# EBIT                                                     3049000000.0
# NetInterestIncome                                        -238000000.0
# InterestExpense                                           322000000.0
# InterestIncome                                             43000000.0
# NormalizedIncome                                    1673744774.477448
# NetIncomeFromContinuingAndDiscontinuedOperation          2412000000.0
# TotalExpenses                                            6856000000.0
# TotalOperatingIncomeAsReported                           3675000000.0
# DilutedAverageShares                                     4274508000.0
# BasicAverageShares                                       4269495000.0
# DilutedEPS                                                       0.56
# BasicEPS                                                         0.56
# DilutedNIAvailtoComStockholders                          2412000000.0
# NetIncomeCommonStockholders                              2412000000.0
# NetIncome                                                2412000000.0
# MinorityInterests                                          21000000.0
# NetIncomeIncludingNoncontrollingInterests                2391000000.0
# NetIncomeDiscontinuousOperations                                  NaN
# NetIncomeContinuousOperations                            2391000000.0
# TaxProvision                                              336000000.0
# PretaxIncome                                             2727000000.0
# OtherIncomeExpense                                        268000000.0
# SpecialIncomeCharges                                      978000000.0
# GainOnSaleOfBusiness                                              NaN
# OtherSpecialCharges                                       166000000.0
# ImpairmentOfCapitalAssets                               -1144000000.0
# EarningsFromEquityInterest                               -574000000.0
# GainOnSaleOfSecurity                                     -136000000.0
# NetNonOperatingInterestIncomeExpense                     -238000000.0
# TotalOtherFinanceCost                                     -41000000.0
# InterestExpenseNonOperating                               322000000.0
# InterestIncomeNonOperating                                 43000000.0
# OperatingIncome                                          2697000000.0
# OperatingExpense                                          575000000.0
# OtherOperatingExpenses                                    244000000.0
# DepreciationAmortizationDepletionIncomeStatement           14000000.0
# DepreciationAndAmortizationInIncomeStatement               14000000.0
# ResearchAndDevelopment                                    192000000.0
# SellingGeneralAndAdministration                           125000000.0
# SellingAndMarketingExpense                                        NaN
# GeneralAndAdministrativeExpense                           125000000.0
# OtherGandA                                                 74000000.0
# SalariesAndWages                                           51000000.0
# GrossProfit                                              3272000000.0
# CostOfRevenue                                            6281000000.0
# TotalRevenue                                             9553000000.0
# OperatingRevenue                                         9542000000.0
#
#                                                       2024-06-30  \
# TaxEffectOfUnusualItems                               80920000.0
# TaxRateForCalcs                                             0.34
# NormalizedEBITDA                                    3031000000.0
# TotalUnusualItems                                    238000000.0
# TotalUnusualItemsExcludingGoodwill                   238000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  2769000000.0
# ReconciledDepreciation                                 9000000.0
# ReconciledCostOfRevenue                             6349000000.0
# EBITDA                                              3269000000.0
# EBIT                                                3260000000.0
# NetInterestIncome                                   -603000000.0
# InterestExpense                                      525000000.0
# InterestIncome                                         3000000.0
# NormalizedIncome                                    2611920000.0
# NetIncomeFromContinuingAndDiscontinuedOperation     2769000000.0
# TotalExpenses                                       6932000000.0
# TotalOperatingIncomeAsReported                      3875000000.0
# DilutedAverageShares                                4279782000.0
# BasicAverageShares                                  4274769000.0
# DilutedEPS                                                  0.65
# BasicEPS                                                    0.65
# DilutedNIAvailtoComStockholders                     2769000000.0
# NetIncomeCommonStockholders                         2769000000.0
# NetIncome                                           2769000000.0
# MinorityInterests                                            0.0
# NetIncomeIncludingNoncontrollingInterests           2769000000.0
# NetIncomeDiscontinuousOperations                             NaN
# NetIncomeContinuousOperations                       2769000000.0
# TaxProvision                                         -34000000.0
# PretaxIncome                                        2735000000.0
# OtherIncomeExpense                                   350000000.0
# SpecialIncomeCharges                                 887000000.0
# GainOnSaleOfBusiness                                1059000000.0
# OtherSpecialCharges                                  123000000.0
# ImpairmentOfCapitalAssets                             49000000.0
# EarningsFromEquityInterest                           112000000.0
# GainOnSaleOfSecurity                                -649000000.0
# NetNonOperatingInterestIncomeExpense                -603000000.0
# TotalOtherFinanceCost                                 81000000.0
# InterestExpenseNonOperating                          525000000.0
# InterestIncomeNonOperating                             3000000.0
# OperatingIncome                                     2988000000.0
# OperatingExpense                                     583000000.0
# OtherOperatingExpenses                               257000000.0
# DepreciationAmortizationDepletionIncomeStatement       9000000.0
# DepreciationAndAmortizationInIncomeStatement           9000000.0
# ResearchAndDevelopment                               189000000.0
# SellingGeneralAndAdministration                      128000000.0
# SellingAndMarketingExpense                                   NaN
# GeneralAndAdministrativeExpense                      128000000.0
# OtherGandA                                            76000000.0
# SalariesAndWages                                      52000000.0
# GrossProfit                                         3571000000.0
# CostOfRevenue                                       6349000000.0
# TotalRevenue                                        9920000000.0
# OperatingRevenue                                    9873000000.0
#
#                                                       2024-03-31  \
# TaxEffectOfUnusualItems                                      0.0
# TaxRateForCalcs                                         0.209836
# NormalizedEBITDA                                    2474000000.0
# TotalUnusualItems                                   -448000000.0
# TotalUnusualItemsExcludingGoodwill                  -448000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  1679000000.0
# ReconciledDepreciation                               714000000.0
# ReconciledCostOfRevenue                             5367000000.0
# EBITDA                                              2474000000.0
# EBIT                                                2474000000.0
# NetInterestIncome                                   -437000000.0
# InterestExpense                                      339000000.0
# InterestIncome                                       109000000.0
# NormalizedIncome                                    1679000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation     1679000000.0
# TotalExpenses                                       6011000000.0
# TotalOperatingIncomeAsReported                      2448000000.0
# DilutedAverageShares                                4280331182.0
# BasicAverageShares                                  4280331182.0
# DilutedEPS                                              0.392259
# BasicEPS                                                0.392259
# DilutedNIAvailtoComStockholders                     1679000000.0
# NetIncomeCommonStockholders                         1679000000.0
# NetIncome                                           1679000000.0
# MinorityInterests                                     -8000000.0
# NetIncomeIncludingNoncontrollingInterests           1687000000.0
# NetIncomeDiscontinuousOperations                             NaN
# NetIncomeContinuousOperations                       1687000000.0
# TaxProvision                                         448000000.0
# PretaxIncome                                        2135000000.0
# OtherIncomeExpense                                   124000000.0
# SpecialIncomeCharges                                -158000000.0
# GainOnSaleOfBusiness                                         NaN
# OtherSpecialCharges                                  152000000.0
# ImpairmentOfCapitalAssets                              6000000.0
# EarningsFromEquityInterest                           124000000.0
# GainOnSaleOfSecurity                                -290000000.0
# NetNonOperatingInterestIncomeExpense                -437000000.0
# TotalOtherFinanceCost                                207000000.0
# InterestExpenseNonOperating                          339000000.0
# InterestIncomeNonOperating                           109000000.0
# OperatingIncome                                     2448000000.0
# OperatingExpense                                     644000000.0
# OtherOperatingExpenses                               348000000.0
# DepreciationAmortizationDepletionIncomeStatement      10000000.0
# DepreciationAndAmortizationInIncomeStatement          10000000.0
# ResearchAndDevelopment                               156000000.0
# SellingGeneralAndAdministration                      140000000.0
# SellingAndMarketingExpense                                   NaN
# GeneralAndAdministrativeExpense                      130000000.0
# OtherGandA                                            63000000.0
# SalariesAndWages                                      67000000.0
# GrossProfit                                         3092000000.0
# CostOfRevenue                                       5367000000.0
# TotalRevenue                                        8459000000.0
# OperatingRevenue                                    8459000000.0
#
#                                                            2023-12-31  \
# TaxEffectOfUnusualItems                             -159980641.066328
# TaxRateForCalcs                                              0.225008
# NormalizedEBITDA                                         5356000000.0
# TotalUnusualItems                                        -711000000.0
# TotalUnusualItemsExcludingGoodwill                       -711000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       2418000000.0
# ReconciledDepreciation                                    855000000.0
# ReconciledCostOfRevenue                                  6046000000.0
# EBITDA                                                   4645000000.0
# EBIT                                                     3790000000.0
# NetInterestIncome                                        -822000000.0
# InterestExpense                                           639000000.0
# InterestIncome                                           -181000000.0
# NormalizedIncome                                    2969019358.933672
# NetIncomeFromContinuingAndDiscontinuedOperation          2418000000.0
# TotalExpenses                                            7218000000.0
# TotalOperatingIncomeAsReported                           5177000000.0
# DilutedAverageShares                                     4317857143.0
# BasicAverageShares                                       4317857143.0
# DilutedEPS                                                       0.56
# BasicEPS                                                         0.56
# DilutedNIAvailtoComStockholders                          2418000000.0
# NetIncomeCommonStockholders                              2418000000.0
# NetIncome                                                2418000000.0
# MinorityInterests                                         -24000000.0
# NetIncomeIncludingNoncontrollingInterests                2442000000.0
# NetIncomeDiscontinuousOperations                                  0.0
# NetIncomeContinuousOperations                            2442000000.0
# TaxProvision                                              709000000.0
# PretaxIncome                                             3151000000.0
# OtherIncomeExpense                                      -1863000000.0
# SpecialIncomeCharges                                     -659000000.0
# GainOnSaleOfBusiness                                              NaN
# OtherSpecialCharges                                       464000000.0
# ImpairmentOfCapitalAssets                                 121000000.0
# EarningsFromEquityInterest                              -1152000000.0
# GainOnSaleOfSecurity                                      -52000000.0
# NetNonOperatingInterestIncomeExpense                     -822000000.0
# TotalOtherFinanceCost                                       2000000.0
# InterestExpenseNonOperating                               639000000.0
# InterestIncomeNonOperating                               -181000000.0
# OperatingIncome                                          5836000000.0
# OperatingExpense                                          327000000.0
# OtherOperatingExpenses                                    -50000000.0
# DepreciationAmortizationDepletionIncomeStatement           10000000.0
# DepreciationAndAmortizationInIncomeStatement               10000000.0
# ResearchAndDevelopment                                    231000000.0
# SellingGeneralAndAdministration                           136000000.0
# SellingAndMarketingExpense                                -39000000.0
# GeneralAndAdministrativeExpense                           175000000.0
# OtherGandA                                                 82000000.0
# SalariesAndWages                                           93000000.0
# GrossProfit                                              6163000000.0
# CostOfRevenue                                            6891000000.0
# TotalRevenue                                            13054000000.0
# OperatingRevenue                                        13011000000.0
#
#                                                            2023-09-30  \
# TaxEffectOfUnusualItems                              -22812332.439678
# TaxRateForCalcs                                               0.04256
# NormalizedEBITDA                                         4597000000.0
# TotalUnusualItems                                        -536000000.0
# TotalUnusualItemsExcludingGoodwill                       -536000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       2836000000.0
# ReconciledDepreciation                                    780000000.0
# ReconciledCostOfRevenue                                  5541000000.0
# EBITDA                                                   4061000000.0
# EBIT                                                     3281000000.0
# NetInterestIncome                                        -307000000.0
# InterestExpense                                           297000000.0
# InterestIncome                                             25000000.0
# NormalizedIncome                                    3349187667.560322
# NetIncomeFromContinuingAndDiscontinuedOperation          2836000000.0
# TotalExpenses                                            6890000000.0
# TotalOperatingIncomeAsReported                           3275000000.0
# DilutedAverageShares                                     4318388000.0
# BasicAverageShares                                       4314556000.0
# DilutedEPS                                                       0.66
# BasicEPS                                                         0.66
# DilutedNIAvailtoComStockholders                          2836000000.0
# NetIncomeCommonStockholders                              2836000000.0
# NetIncome                                                2836000000.0
# MinorityInterests                                         -21000000.0
# NetIncomeIncludingNoncontrollingInterests                2857000000.0
# NetIncomeDiscontinuousOperations                                  0.0
# NetIncomeContinuousOperations                            2857000000.0
# TaxProvision                                              127000000.0
# PretaxIncome                                             2984000000.0
# OtherIncomeExpense                                       -442000000.0
# SpecialIncomeCharges                                     -458000000.0
# GainOnSaleOfBusiness                                              NaN
# OtherSpecialCharges                                       383000000.0
# ImpairmentOfCapitalAssets                                  75000000.0
# EarningsFromEquityInterest                                 94000000.0
# GainOnSaleOfSecurity                                      -78000000.0
# NetNonOperatingInterestIncomeExpense                     -307000000.0
# TotalOtherFinanceCost                                      35000000.0
# InterestExpenseNonOperating                               297000000.0
# InterestIncomeNonOperating                                 25000000.0
# OperatingIncome                                          3733000000.0
# OperatingExpense                                          581000000.0
# OtherOperatingExpenses                                    243000000.0
# DepreciationAmortizationDepletionIncomeStatement           12000000.0
# DepreciationAndAmortizationInIncomeStatement               12000000.0
# ResearchAndDevelopment                                    188000000.0
# SellingGeneralAndAdministration                           138000000.0
# SellingAndMarketingExpense                                 26000000.0
# GeneralAndAdministrativeExpense                           138000000.0
# OtherGandA                                                 73000000.0
# SalariesAndWages                                           65000000.0
# GrossProfit                                              4314000000.0
# CostOfRevenue                                            6309000000.0
# TotalRevenue                                            10623000000.0
# OperatingRevenue                                        10581000000.0
#
#                                                     2023-06-30
# TaxEffectOfUnusualItems                                    NaN
# TaxRateForCalcs                                            NaN
# NormalizedEBITDA                                           NaN
# TotalUnusualItems                                          NaN
# TotalUnusualItemsExcludingGoodwill                         NaN
# NetIncomeFromContinuingOperationNetMinorityInte...         NaN
# ReconciledDepreciation                                     NaN
# ReconciledCostOfRevenue                                    NaN
# EBITDA                                                     NaN
# EBIT                                                       NaN
# NetInterestIncome                                          NaN
# InterestExpense                                            NaN
# InterestIncome                                             NaN
# NormalizedIncome                                           NaN
# NetIncomeFromContinuingAndDiscontinuedOperation            NaN
# TotalExpenses                                              NaN
# TotalOperatingIncomeAsReported                             NaN
# DilutedAverageShares                                       NaN
# BasicAverageShares                                         NaN
# DilutedEPS                                                 NaN
# BasicEPS                                                   NaN
# DilutedNIAvailtoComStockholders                            NaN
# NetIncomeCommonStockholders                                NaN
# NetIncome                                                  NaN
# MinorityInterests                                          NaN
# NetIncomeIncludingNoncontrollingInterests                  NaN
# NetIncomeDiscontinuousOperations                           0.0
# NetIncomeContinuousOperations                              NaN
# TaxProvision                                               NaN
# PretaxIncome                                               NaN
# OtherIncomeExpense                                         NaN
# SpecialIncomeCharges                                       NaN
# GainOnSaleOfBusiness                                       NaN
# OtherSpecialCharges                                        NaN
# ImpairmentOfCapitalAssets                                  NaN
# EarningsFromEquityInterest                                 NaN
# GainOnSaleOfSecurity                                       NaN
# NetNonOperatingInterestIncomeExpense                       NaN
# TotalOtherFinanceCost                                      NaN
# InterestExpenseNonOperating                                NaN
# InterestIncomeNonOperating                                 NaN
# OperatingIncome                                            NaN
# OperatingExpense                                           NaN
# OtherOperatingExpenses                                     NaN
# DepreciationAmortizationDepletionIncomeStatement           NaN
# DepreciationAndAmortizationInIncomeStatement               NaN
# ResearchAndDevelopment                                     NaN
# SellingGeneralAndAdministration                            NaN
# SellingAndMarketingExpense                          21000000.0
# GeneralAndAdministrativeExpense                            NaN
# OtherGandA                                                 NaN
# SalariesAndWages                                           NaN
# GrossProfit                                                NaN
# CostOfRevenue                                              NaN
# TotalRevenue                                               NaN
# OperatingRevenue                                           NaN

# %%
dre = pd.DataFrame(dre)
dre = dre/1000
dre = dre [dre.columns[::-1]]
dre
# Out:
#                                                    2023-06-30 2023-09-30  \
# TaxEffectOfUnusualItems                                   NaN  -0.000023
# TaxRateForCalcs                                           NaN        0.0
# NormalizedEBITDA                                          NaN   0.004597
# TotalUnusualItems                                         NaN  -0.000536
# TotalUnusualItemsExcludingGoodwill                        NaN  -0.000536
# NetIncomeFromContinuingOperationNetMinorityInte...        NaN   0.002836
# ReconciledDepreciation                                    NaN    0.00078
# ReconciledCostOfRevenue                                   NaN   0.005541
# EBITDA                                                    NaN   0.004061
# EBIT                                                      NaN   0.003281
# NetInterestIncome                                         NaN  -0.000307
# InterestExpense                                           NaN   0.000297
# InterestIncome                                            NaN   0.000025
# NormalizedIncome                                          NaN   0.003349
# NetIncomeFromContinuingAndDiscontinuedOperation           NaN   0.002836
# TotalExpenses                                             NaN    0.00689
# TotalOperatingIncomeAsReported                            NaN   0.003275
# DilutedAverageShares                                      NaN   0.004318
# BasicAverageShares                                        NaN   0.004315
# DilutedEPS                                                NaN        0.0
# BasicEPS                                                  NaN        0.0
# DilutedNIAvailtoComStockholders                           NaN   0.002836
# NetIncomeCommonStockholders                               NaN   0.002836
# NetIncome                                                 NaN   0.002836
# MinorityInterests                                         NaN  -0.000021
# NetIncomeIncludingNoncontrollingInterests                 NaN   0.002857
# NetIncomeDiscontinuousOperations                          0.0        0.0
# NetIncomeContinuousOperations                             NaN   0.002857
# TaxProvision                                              NaN   0.000127
# PretaxIncome                                              NaN   0.002984
# OtherIncomeExpense                                        NaN  -0.000442
# SpecialIncomeCharges                                      NaN  -0.000458
# GainOnSaleOfBusiness                                      NaN        NaN
# OtherSpecialCharges                                       NaN   0.000383
# ImpairmentOfCapitalAssets                                 NaN   0.000075
# EarningsFromEquityInterest                                NaN   0.000094
# GainOnSaleOfSecurity                                      NaN  -0.000078
# NetNonOperatingInterestIncomeExpense                      NaN  -0.000307
# TotalOtherFinanceCost                                     NaN   0.000035
# InterestExpenseNonOperating                               NaN   0.000297
# InterestIncomeNonOperating                                NaN   0.000025
# OperatingIncome                                           NaN   0.003733
# OperatingExpense                                          NaN   0.000581
# OtherOperatingExpenses                                    NaN   0.000243
# DepreciationAmortizationDepletionIncomeStatement          NaN   0.000012
# DepreciationAndAmortizationInIncomeStatement              NaN   0.000012
# ResearchAndDevelopment                                    NaN   0.000188
# SellingGeneralAndAdministration                           NaN   0.000138
# SellingAndMarketingExpense                           0.000021   0.000026
# GeneralAndAdministrativeExpense                           NaN   0.000138
# OtherGandA                                                NaN   0.000073
# SalariesAndWages                                          NaN   0.000065
# GrossProfit                                               NaN   0.004314
# CostOfRevenue                                             NaN   0.006309
# TotalRevenue                                              NaN   0.010623
# OperatingRevenue                                          NaN   0.010581
#
#                                                    2023-12-31 2024-03-31  \
# TaxEffectOfUnusualItems                              -0.00016        0.0
# TaxRateForCalcs                                           0.0        0.0
# NormalizedEBITDA                                     0.005356   0.002474
# TotalUnusualItems                                   -0.000711  -0.000448
# TotalUnusualItemsExcludingGoodwill                  -0.000711  -0.000448
# NetIncomeFromContinuingOperationNetMinorityInte...   0.002418   0.001679
# ReconciledDepreciation                               0.000855   0.000714
# ReconciledCostOfRevenue                              0.006046   0.005367
# EBITDA                                               0.004645   0.002474
# EBIT                                                  0.00379   0.002474
# NetInterestIncome                                   -0.000822  -0.000437
# InterestExpense                                      0.000639   0.000339
# InterestIncome                                      -0.000181   0.000109
# NormalizedIncome                                     0.002969   0.001679
# NetIncomeFromContinuingAndDiscontinuedOperation      0.002418   0.001679
# TotalExpenses                                        0.007218   0.006011
# TotalOperatingIncomeAsReported                       0.005177   0.002448
# DilutedAverageShares                                 0.004318    0.00428
# BasicAverageShares                                   0.004318    0.00428
# DilutedEPS                                                0.0        0.0
# BasicEPS                                                  0.0        0.0
# DilutedNIAvailtoComStockholders                      0.002418   0.001679
# NetIncomeCommonStockholders                          0.002418   0.001679
# NetIncome                                            0.002418   0.001679
# MinorityInterests                                   -0.000024  -0.000008
# NetIncomeIncludingNoncontrollingInterests            0.002442   0.001687
# NetIncomeDiscontinuousOperations                          0.0        NaN
# NetIncomeContinuousOperations                        0.002442   0.001687
# TaxProvision                                         0.000709   0.000448
# PretaxIncome                                         0.003151   0.002135
# OtherIncomeExpense                                  -0.001863   0.000124
# SpecialIncomeCharges                                -0.000659  -0.000158
# GainOnSaleOfBusiness                                      NaN        NaN
# OtherSpecialCharges                                  0.000464   0.000152
# ImpairmentOfCapitalAssets                            0.000121   0.000006
# EarningsFromEquityInterest                          -0.001152   0.000124
# GainOnSaleOfSecurity                                -0.000052   -0.00029
# NetNonOperatingInterestIncomeExpense                -0.000822  -0.000437
# TotalOtherFinanceCost                                0.000002   0.000207
# InterestExpenseNonOperating                          0.000639   0.000339
# InterestIncomeNonOperating                          -0.000181   0.000109
# OperatingIncome                                      0.005836   0.002448
# OperatingExpense                                     0.000327   0.000644
# OtherOperatingExpenses                               -0.00005   0.000348
# DepreciationAmortizationDepletionIncomeStatement      0.00001    0.00001
# DepreciationAndAmortizationInIncomeStatement          0.00001    0.00001
# ResearchAndDevelopment                               0.000231   0.000156
# SellingGeneralAndAdministration                      0.000136    0.00014
# SellingAndMarketingExpense                          -0.000039        NaN
# GeneralAndAdministrativeExpense                      0.000175    0.00013
# OtherGandA                                           0.000082   0.000063
# SalariesAndWages                                     0.000093   0.000067
# GrossProfit                                          0.006163   0.003092
# CostOfRevenue                                        0.006891   0.005367
# TotalRevenue                                         0.013054   0.008459
# OperatingRevenue                                     0.013011   0.008459
#
#                                                    2024-06-30 2024-09-30
# TaxEffectOfUnusualItems                              0.000081   0.000104
# TaxRateForCalcs                                           0.0        0.0
# NormalizedEBITDA                                     0.003031   0.002955
# TotalUnusualItems                                    0.000238   0.000842
# TotalUnusualItemsExcludingGoodwill                   0.000238   0.000842
# NetIncomeFromContinuingOperationNetMinorityInte...   0.002769   0.002412
# ReconciledDepreciation                               0.000009   0.000748
# ReconciledCostOfRevenue                              0.006349   0.005547
# EBITDA                                               0.003269   0.003797
# EBIT                                                  0.00326   0.003049
# NetInterestIncome                                   -0.000603  -0.000238
# InterestExpense                                      0.000525   0.000322
# InterestIncome                                       0.000003   0.000043
# NormalizedIncome                                     0.002612   0.001674
# NetIncomeFromContinuingAndDiscontinuedOperation      0.002769   0.002412
# TotalExpenses                                        0.006932   0.006856
# TotalOperatingIncomeAsReported                       0.003875   0.003675
# DilutedAverageShares                                  0.00428   0.004275
# BasicAverageShares                                   0.004275   0.004269
# DilutedEPS                                                0.0        0.0
# BasicEPS                                                  0.0        0.0
# DilutedNIAvailtoComStockholders                      0.002769   0.002412
# NetIncomeCommonStockholders                          0.002769   0.002412
# NetIncome                                            0.002769   0.002412
# MinorityInterests                                         0.0   0.000021
# NetIncomeIncludingNoncontrollingInterests            0.002769   0.002391
# NetIncomeDiscontinuousOperations                          NaN        NaN
# NetIncomeContinuousOperations                        0.002769   0.002391
# TaxProvision                                        -0.000034   0.000336
# PretaxIncome                                         0.002735   0.002727
# OtherIncomeExpense                                    0.00035   0.000268
# SpecialIncomeCharges                                 0.000887   0.000978
# GainOnSaleOfBusiness                                 0.001059        NaN
# OtherSpecialCharges                                  0.000123   0.000166
# ImpairmentOfCapitalAssets                            0.000049  -0.001144
# EarningsFromEquityInterest                           0.000112  -0.000574
# GainOnSaleOfSecurity                                -0.000649  -0.000136
# NetNonOperatingInterestIncomeExpense                -0.000603  -0.000238
# TotalOtherFinanceCost                                0.000081  -0.000041
# InterestExpenseNonOperating                          0.000525   0.000322
# InterestIncomeNonOperating                           0.000003   0.000043
# OperatingIncome                                      0.002988   0.002697
# OperatingExpense                                     0.000583   0.000575
# OtherOperatingExpenses                               0.000257   0.000244
# DepreciationAmortizationDepletionIncomeStatement     0.000009   0.000014
# DepreciationAndAmortizationInIncomeStatement         0.000009   0.000014
# ResearchAndDevelopment                               0.000189   0.000192
# SellingGeneralAndAdministration                      0.000128   0.000125
# SellingAndMarketingExpense                                NaN        NaN
# GeneralAndAdministrativeExpense                      0.000128   0.000125
# OtherGandA                                           0.000076   0.000074
# SalariesAndWages                                     0.000052   0.000051
# GrossProfit                                          0.003571   0.003272
# CostOfRevenue                                        0.006349   0.006281
# TotalRevenue                                          0.00992   0.009553
# OperatingRevenue                                     0.009873   0.009542

# %% [markdown]
# ###Dados Anuais

# %%
bal = ativo.get_balance_sheet(freq='yearly')
bal
# Out:
#                                                2023-12-31     2022-12-31  \
# TreasurySharesNumber                          239153280.0    295810551.0
# OrdinarySharesNumber                         4299854288.0   4483078700.0
# ShareIssued                                  4539007568.0   4778889251.0
# NetDebt                                     11736000000.0   9170000000.0
# TotalDebt                                   16797000000.0  15437000000.0
# ...                                                   ...            ...
# AllowanceForDoubtfulAccountsReceivable        -44000000.0    -43000000.0
# GrossAccountsReceivable                      4241000000.0   4362000000.0
# CashCashEquivalentsAndShortTermInvestments   3660000000.0   4797000000.0
# OtherShortTermInvestments                      51000000.0     61000000.0
# CashAndCashEquivalents                       3609000000.0   4736000000.0
#
#                                                2021-12-31     2020-12-31
# TreasurySharesNumber                          292841474.0    154563828.0
# OrdinarySharesNumber                         4839616924.0   5129910942.0
# ShareIssued                                  5132458398.0   5284474770.0
# NetDebt                                      3878000000.0   6338000000.0
# TotalDebt                                   17201000000.0  19825000000.0
# ...                                                   ...            ...
# AllowanceForDoubtfulAccountsReceivable        -48000000.0    -50000000.0
# GrossAccountsReceivable                      3962000000.0   5043000000.0
# CashCashEquivalentsAndShortTermInvestments  11905000000.0  14258000000.0
# OtherShortTermInvestments                     184000000.0    771000000.0
# CashAndCashEquivalents                      11721000000.0  13487000000.0
#
# [96 rows x 4 columns]

# %%
balanco = pd.DataFrame(bal)
balanco = balanco/1000
balanco = balanco[balanco.columns[::-1]]
balanco
# Out:
#                                              2020-12-31   2021-12-31  \
# TreasurySharesNumber                         154563.828   292841.474
# OrdinarySharesNumber                        5129910.942  4839616.924
# ShareIssued                                  5284474.77  5132458.398
# NetDebt                                       6338000.0    3878000.0
# TotalDebt                                    19825000.0   17201000.0
# ...                                                 ...          ...
# AllowanceForDoubtfulAccountsReceivable         -50000.0     -48000.0
# GrossAccountsReceivable                       5043000.0    3962000.0
# CashCashEquivalentsAndShortTermInvestments   14258000.0   11905000.0
# OtherShortTermInvestments                      771000.0     184000.0
# CashAndCashEquivalents                       13487000.0   11721000.0
#
#                                              2022-12-31   2023-12-31
# TreasurySharesNumber                         295810.551    239153.28
# OrdinarySharesNumber                          4483078.7  4299854.288
# ShareIssued                                 4778889.251  4539007.568
# NetDebt                                       9170000.0   11736000.0
# TotalDebt                                    15437000.0   16797000.0
# ...                                                 ...          ...
# AllowanceForDoubtfulAccountsReceivable         -43000.0     -44000.0
# GrossAccountsReceivable                       4362000.0    4241000.0
# CashCashEquivalentsAndShortTermInvestments    4797000.0    3660000.0
# OtherShortTermInvestments                       61000.0      51000.0
# CashAndCashEquivalents                        4736000.0    3609000.0
#
# [96 rows x 4 columns]

# %% [markdown]
# ### Avaliação Fundamentalista

# %%
fig = make_subplots(rows=2,
                    cols=2,
                    row_heights=[5,5],
                    column_widths=[3,3],
                    subplot_titles=('EBITDA','Lucro Líquido', 'Dívida Líquida', 'Dívida Total'),
                    shared_xaxes=False)
fig.add_trace(go.Bar(name='EBTIDA',x=dre.columns, y=dre.loc['EBITDA']), row=1, col=1)
fig.add_trace(go.Bar(name='Lucro Líquido',x=dre.columns, y=dre.loc['NetIncome']), row=1, col=2)

fig.add_trace(go.Bar(name='Dívida Líquida',x=balanco.columns, y=balanco.loc['NetDebt']), row=2, col=1)
fig.add_trace(go.Bar(name='Dívida Total',x=balanco.columns, y=balanco.loc['TotalDebt']), row=2, col=2)
fig.update_layout(title_text='<b>Avaliação Fundamentalista <b>',
                    template= 'plotly_dark', #template pré-definido da plotly
                    showlegend=False, #esconder ou mostrar legenda
                  height=500, #altura
                  width=800) #largura

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a026eb11-3812-46cb-9c18-420e0a589810" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a026eb11-3812-46cb-9c18-420e0a589810")) {                    Plotly.newPlot(                        "a026eb11-3812-46cb-9c18-420e0a589810",                        [{"name":"EBTIDA","x":["2023-06-30T00:00:00","2023-09-30T00:00:00","2023-12-31T00:00:00","2024-03-31T00:00:00","2024-06-30T00:00:00","2024-09-30T00:00:00"],"y":[null,0.004061,0.004645,0.002474,0.003269,0.003797],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Lucro Líquido","x":["2023-06-30T00:00:00","2023-09-30T00:00:00","2023-12-31T00:00:00","2024-03-31T00:00:00","2024-06-30T00:00:00","2024-09-30T00:00:00"],"y":[null,0.002836,0.002418,0.0016790000000000002,0.002769,0.002412],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Dívida Líquida","x":["2020-12-31T00:00:00","2021-12-31T00:00:00","2022-12-31T00:00:00","2023-12-31T00:00:00"],"y":[6338000.0,3878000.0,9170000.0,11736000.0],"type":"bar","xaxis":"x3","yaxis":"y3"},{"name":"Dívida Total","x":["2020-12-31T00:00:00","2021-12-31T00:00:00","2022-12-31T00:00:00","2023-12-31T00:00:00"],"y":[19825000.0,17201000.0,15437000.0,16797000.0],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333 ...
